# %% [markdown]
# # Gráficos do modelo SIRD do ebola em Guiné

# %%
from config import *
from data_processing import *
from visualization import *

df_normalizado = normalizar_df(DATAPATH, HABITANTES)
plotar_grafico(df_normalizado, 'Modelo SIRD - Ebola', y_scale='log', y_lim=(1e-6, 1.30))
