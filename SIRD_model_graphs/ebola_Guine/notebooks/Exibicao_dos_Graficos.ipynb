# %% [markdown]
# # Gráfico Dinâmico de Epidemia
# ### Modelo de análise: SIRD (Susceptible, Infected, Recovered, Deceased)
# ### Epidemia: Ebola
# ### País: Guiné
# ### Período: 2014-2016
# ---

# %% [markdown]
# # Plotando gráfico original
# > Escala logarítmica

# %%
from pathlib import Path
import sys

PROJECT_ROOT = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / 'src').is_dir() and (path / 'data').is_dir()
)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import *
from src.data_processing import *
from src.visualization import *
from src.math_models import *

df_normalizado = normalizar_df(PROJECT_ROOT / DATAPATH, HABITANTES)
plotar_grafico(df_normalizado, 'Modelo SIRD - Ebola em Guiné - 2014-2016', 'log', (1e-6, 1.30))

# %% [markdown]
# # Gráfico suavizado
# > Aplica regressão local

# %%
df_suavizado = suavizar_df(df_normalizado)
plotar_grafico(df_suavizado, 'Gráfico suavizado', 'log', (1e-6, 1.30))
